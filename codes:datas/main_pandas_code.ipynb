# %%
import pandas as pd
tweets_df = pd.read_json('data_final.json', lines=True)
tweets_df.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2020-08-08 23:59:41+00:00  1292249150797623297  1292249150797623296
# 1 2020-08-08 23:59:25+00:00  1292249086666498048  1292249086666498048
# 2 2020-08-08 23:59:05+00:00  1292249003841785856  1292249003841785856
# 3 2020-08-08 23:58:50+00:00  1292248938758668288  1292248938758668288
# 4 2020-08-08 23:58:37+00:00  1292248886090674176  1292248886090674176
#
#                                            full_text  truncated  \
# 0  @drrajivb Hi Dr. Bhatia. My wife and I are hav...      False
# 1  The RNC has spent $20 million to prevent votin...      False
# 2  Niggas be like I want some dick but I can't ho...      False
# 3  You really can't make this stuff up. As Columb...      False
# 4  Right wingers are literally brain dead. They’v...      False
#
#   display_text_range                                           entities  \
# 0           [0, 278]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
pd.set_option('display.max_columns', None)
tweets_filtered = tweets_df[tweets_df.coordinates.notnull()]
len(tweets_filtered)
# Out:
# 2263

# %%
tweets_df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'metadata', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'lang', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status', 'possibly_sensitive',
#        'extended_entities'],
#       dtype='object')

# %%
tweets_df["lang"]
# Out:
# 0        en
# 1        en
# 2        en
# 3        en
# 4        en
#          ..
# 39995    en
# 39996    en
# 39997    en
# 39998    en
# 39999    en
# Name: lang, Length: 40000, dtype: object
